# %% [markdown]
# # EDA Project

# %% [markdown]
# # 1.Loading the dataset into pandas and providing a summary of columns in the               loaded dataset without any modification.

# %%
# Importing the required libraries.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pingouin as pg
# Out:
# C:\Users\ADESH\anaconda3\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.4.0, the latest is 0.5.0.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
#Importing the dataset of online electronics purchase survey 
ds  = pd.read_csv("C:/Users/ADESH/OneDrive/Desktop/dataset/all_data_copy.csv")
ds.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   141234                      iPhone                1        700
# 1   141235    Lightning Charging Cable                1      14.95
# 2   141236            Wired Headphones                2      11.99
# 3   141237            27in FHD Monitor                1     149.99
# 4   141238            Wired Headphones                1      11.99
# 5   141239      AAA Batteries (4-pack)                1       2.99
# 6   141240      27in 4K Gaming Monitor                1     389.99
# 7   141241        USB-C Charging Cable                1      11.95
# 8   141242  Bose SoundSport Headphones                1      99.99
# 9   141243    Apple Airpods Headphones                1        150
#
#        Order Date                         Purchase Address
# 0  01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15         185 Maple St, Portland, OR 97035
# ...

# %%
ds.tail(10)
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 373690   259349    AAA Batteries (4-pack)                1       2.99
# 373691   259350              Google Phone                1        600
# 373692   259350      USB-C Charging Cable                1      11.95
# 373693   259351  Apple Airpods Headphones                1        150
# 373694   259352      USB-C Charging Cable                1      11.95
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 373690  09/01/19 22:14           911 River St, Dallas, TX 75001
# 373691  09/30/19 13:49    519 Maple St, San Francisco, CA 94016
# ...

# %%
'''Given dataset having data of online shopping of electronics products.
   Data contain number of elctronics product range like mobile phone,mobile accessories,moniters,laptops etc.
   In our dataset we have Quantity of that order ptoducts and price for each.
   we also have order date and order time in hours.
   Finally we have in detailed purchase address with city name and postal code  where they products are sold.
   '''
# Out:
# 'Given dataset having data of online shopping of electronics products.\n   Data contain number of elctronics product range like mobile phone,mobile accessories,moniters,laptops etc.\n   In our dataset we have Quantity of that order ptoducts and price for each.\n   we also have order date and order time in hours.\n   Finally we have in detailed purchase address with city name and postal code  where they products are sold.\n   '

# %% [markdown]
# # 2.Prepare the data frame for further analysis. Clean it, mold it in any manner you see fit.

# %%
# Making backup dataset
ds1 = ds.copy()

# %%
# missing value imputation
ds.isnull().sum()
# Out:
# Order ID            1090
# Product             1090
# Quantity Ordered    1090
# Price Each          1090
# Order Date          1090
# Purchase Address    1090
# dtype: int64

# %%
'''Here we can see 1090 rows are NaN so we dont need it we are going to remove all the NaN values'''
# Out:
# 'Here we can see 1090 rows are NaN so we dont need it we are going to remove all the NaN values'

# %%
# To check NaN values
nan = ds[ds.isna().any(axis=1)] 
nan.tail()
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 372026      NaN     NaN              NaN        NaN        NaN
# 372288      NaN     NaN              NaN        NaN        NaN
# 372892      NaN     NaN              NaN        NaN        NaN
# 373398      NaN     NaN              NaN        NaN        NaN
# 373676      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 372026              NaN
# 372288              NaN
# 372892              NaN
# 373398              NaN
# 373676              NaN

# %%
''' Cheking the null/NaN values.'''
# Out:
# ' Cheking the null/NaN values.'

# %%
# removing all null values 
ds.dropna(how='all', inplace=True)
ds.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
'''Now no any missing values or NaN Values in our dataset'''
# Out:
# 'Now no any missing values or NaN Values in our dataset'

# %%
#data types of each column.
ds.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372610 entries, 0 to 373699
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          372610 non-null  object
#  1   Product           372610 non-null  object
#  2   Quantity Ordered  372610 non-null  object
#  3   Price Each        372610 non-null  object
#  4   Order Date        372610 non-null  object
#  5   Purchase Address  372610 non-null  object
# dtypes: object(6)
# memory usage: 19.9+ MB

# %%
'''Our all columns have dtype object. '''
# Out:
# 'Our all columns have dtype object. '

# %%
# removing spaces between column names
ds.columns = ['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'Order_Date', 'Purchase_Address']
ds.head(1)
# Out:
#   Order_ID Product Quantity_Ordered Price_Each      Order_Date  \
# 0   141234  iPhone                1        700  01/22/19 21:25
#
#                   Purchase_Address
# 0  944 Walnut St, Boston, MA 02215

# %%
'''We just remove speces from column names'''
# Out:
# 'We just remove speces from column names'

# %%
# we need date and month seaperate column
ds['Date'] = ds['Order_Date'].str[:8]
ds['Month'] = ds['Order_Date'].str[:2]
ds.head()
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order_Date                       Purchase_Address      Date Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  01/05/19    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  01/25/19    01

# %%
# Counting month column values
ds.Month.value_counts()
# Out:
# 12    49968
# 10    40564
# 04    36558
# 11    35146
# 05    33132
# 03    30306
# 07    28586
# 06    27108
# 02    23950
# 08    23922
# 09    23242
# 01    19418
# Or      710
# Name: Month, dtype: int64

# %%
'''Here we see 'Or' values in month column we have to remove it '''
# Out:
# "Here we see 'Or' values in month column we have to remove it "

# %%
ds = ds[ds['Order_Date'].str[:2] != 'Or']
ds.head()
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order_Date                       Purchase_Address      Date Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  01/22/19    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  01/28/19    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  01/17/19    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  01/05/19    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  01/25/19    01

# %%
'''Here we niglect that Or vslues '''
# Out:
# 'Here we niglect that Or vslues '

# %%
# Converting the datatype of dates and month 
ds['Order_Date'] = pd.to_datetime(ds['Order_Date'])

# %%
ds['Date'] = pd.to_datetime(ds['Date'])
ds['Month'] = ds['Month'].astype('int32')
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371900 entries, 0 to 373699
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          371900 non-null  object
#  1   Product           371900 non-null  object
#  2   Quantity_Ordered  371900 non-null  object
#  3   Price_Each        371900 non-null  object
#  4   Order_Date        371900 non-null  datetime64[ns]
#  5   Purchase_Address  371900 non-null  object
#  6   Date              371900 non-null  datetime64[ns]
#  7   Month             371900 non-null  int32
# dtypes: datetime64[ns](2), int32(1), object(5)
# memory usage: 24.1+ MB

# %%
'''Now our Date  having datatype as Datetime'''
# Out:
# 'Now our Date  having datatype as Datetime'

# %%
# Separating month, year, date and weekday
ds['Month'] = ds.Date.dt.month
ds['Year'] = ds.Date.dt.year
ds['date'] = ds.Date.dt.day
ds.head()
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#            Order_Date                       Purchase_Address       Date  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035 2019-01-28
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016 2019-01-17
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001 2019-01-05
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301 2019-01-25
#
#    Month  Year  date
# 0      1  2019    22
# 1      1  2019    28
# 2      1  2019    17
# 3      1  2019     5
# 4      1  2019    25

# %%
'''Now we have seaperate date month and year column'''
# Out:
# 'Now we have seaperate date month and year column'

# %%
# value count of order ID column
ds.Order_ID.value_counts()
# Out:
# 160873    10
# 277875     8
# 312407     8
# 226625     8
# 235798     8
#           ..
# 209363     2
# 298817     2
# 150128     2
# 200809     2
# 165970     2
# Name: Order_ID, Length: 178437, dtype: int64

# %%
'''We have repetated Order ID values thats why we need to remove The column'''
# Out:
# 'We have repetated Order ID values thats why we need to remove The column'

# %%
# value count of Product column
ds.Product.value_counts()
# Out:
# USB-C Charging Cable          43806
# Lightning Charging Cable      43316
# AAA Batteries (4-pack)        41282
# AA Batteries (4-pack)         41154
# Wired Headphones              37764
# Apple Airpods Headphones      31098
# Bose SoundSport Headphones    26650
# 27in FHD Monitor              15014
# iPhone                        13684
# 27in 4K Gaming Monitor        12460
# 34in Ultrawide Monitor        12362
# Google Phone                  11050
# Flatscreen TV                  9600
# Macbook Pro Laptop             9448
# ThinkPad Laptop                8256
# 20in Monitor                   8202
# Vareebadd Phone                4130
# LG Washing Machine             1332
# LG Dryer                       1292
# Name: Product, dtype: int64

# %%
''' We have 20 types of product range'''
# Out:
# ' We have 20 types of product range'

# %%
# value count of Quantity_ Orderd column
ds.Quantity_Ordered.value_counts()
# Out:
# 1    337104
# 2     26648
# 3      5840
# 4      1612
# 5       472
# 6       160
# 7        48
# 8        10
# 9         6
# Name: Quantity_Ordered, dtype: int64

# %%
'''We have total 9 number of Order Quantity, but dtype is int64 we have to convert it into integer'''
# Out:
# 'We have total 9 number of Order Quantity, but dtype is int64 we have to convert it into integer'

# %%
# value count of Quantity_ Orderd column
ds.Price_Each.value_counts()
# Out:
# 11.95     43806
# 14.95     43316
# 2.99      41282
# 3.84      41154
# 11.99     37764
# 150       30900
# 99.99     26650
# 149.99    15014
# 700       13608
# 389.99    12460
# 379.99    12362
# 600       10980
# 300        9560
# 1700       9404
# 999.99     8256
# 109.99     8202
# 400        4112
# 600.0      2694
# 150.0       198
# 700.0        76
# 1700.0       44
# 300.0        40
# 400.0        18
# Name: Price_Each, dtype: int64

# %%
'''For cost column we have dtype int64 so we have to convert it into float no'''
# Out:
# 'For cost column we have dtype int64 so we have to convert it into float no'

# %%
#All the values in Quantity Ordered column have to convert it into Integer and Price Column to float.
ds['Quantity_Ordered'] = ds['Quantity_Ordered'].astype('int32')
ds['Price_Each'] = ds['Price_Each'].astype('float64')
ds['Month'] = ds['Month'].astype('int32')
ds['Year'] = ds['Year'].astype('int32')
ds['date'] = ds['date'].astype('int32')

ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371900 entries, 0 to 373699
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          371900 non-null  object
#  1   Product           371900 non-null  object
#  2   Quantity_Ordered  371900 non-null  int32
#  3   Price_Each        371900 non-null  float64
#  4   Order_Date        371900 non-null  datetime64[ns]
#  5   Purchase_Address  371900 non-null  object
#  6   Date              371900 non-null  datetime64[ns]
#  7   Month             371900 non-null  int32
#  8   Year              371900 non-null  int32
#  9   date              371900 non-null  int32
# dtypes: datetime64[ns](2), float64(1), int32(4), object(3)
# memory usage: 25.5+ MB

# %%
# So now we have 4 Integer Columns and 1 Float Column.

# %%
# describe all data
ds.describe()
# Out:
#        Quantity_Ordered     Price_Each          Month           Year  \
# count     371900.000000  371900.000000  371900.000000  371900.000000
# mean           1.124383     184.399735       7.059140    2019.000183
# std            0.442792     332.730883       3.502991       0.013521
# min            1.000000       2.990000       1.000000    2019.000000
# 25%            1.000000      11.950000       4.000000    2019.000000
# 50%            1.000000      14.950000       7.000000    2019.000000
# 75%            1.000000     150.000000      10.000000    2019.000000
# max            9.000000    1700.000000      12.000000    2020.000000
#
#                 date
# count  371900.000000
# mean       15.759532
# std         8.782165
# min         1.000000
# 25%         8.000000
# 50%        16.000000
# 75%        23.000000
# max        31.000000

# %%
#split our address into three columns for easy use
ds[['House_No','City','Pin_Code']]=ds.Purchase_Address.str.split(",",expand=True)

# %%
ds.head(1)
# Out:
#   Order_ID Product  Quantity_Ordered  Price_Each          Order_Date  \
# 0   141234  iPhone                 1       700.0 2019-01-22 21:25:00
#
#                   Purchase_Address       Date  Month  Year  date  \
# 0  944 Walnut St, Boston, MA 02215 2019-01-22      1  2019    22
#
#         House_No     City   Pin_Code
# 0  944 Walnut St   Boston   MA 02215

# %%
'''Here we split our address into three columns for easy use.
   We rename some columns with some meaningfull name.
   '''
# Out:
# 'Here we split our address into three columns for easy use.\n   We rename some columns with some meaningfull name.\n   '

# %%
# Making sales column
ds['Sales'] = ds['Quantity_Ordered'] * ds['Price_Each']
ds.head()
# Out:
#   Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order_Date                       Purchase_Address       Date  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035 2019-01-28
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016 2019-01-17
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001 2019-01-05
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301 2019-01-25
#
#    Month  Year  date       House_No            City   Pin_Code   Sales
# ...

# %%
ds['Sales']= ds['Sales'].astype('float64')

# %% [markdown]
# # 3.Provide a summary of the cleaned dataset along with some preliminary analysis and contrast it with the uncleaned dataset

# %%
ds.head(5)
# Out:
#   Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order_Date                       Purchase_Address       Date  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035 2019-01-28
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016 2019-01-17
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001 2019-01-05
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301 2019-01-25
#
#    Month  Year  date       House_No            City   Pin_Code   Sales
# ...

# %%
'''So in first step we use  data cleaning,renaming, dropping methods.
   Finally we have a data in which Order_Date column is split into three columns such as Date,Month,Year.
   We split Purchase_Address into three columns for easy use like House_No , City , pin- Code.
   We make new Sales column which contain total Amount of order.
   Now we have clean n synchronize data for further use.
   
   Column Names And Description:
   
   Order_ID--> Customer order ID number.
   Product-->  Electronics products range / Type of product.
   Quantity_Ordered--> No of Quantity order by customers.
   Price_Each--> Price of each indivisual product.
   Date--> customer purchse product date.
   Month--. Month column having pruduct perchase months. 
   House_No--> House number from where product is purchase
   City --> City of purchase address
   Pin_Code --> Pin_Code of that purchase address area 
   Sales--> Total amount paid by customers.'''
# Out:
# 'So in first step we use  data cleaning,renaming, dropping methods.\n   Finally we have a data in which Order_Date column is split into three columns such as Date,Month,Year.\n   We split Purchase_Address into three columns for easy use like House_No , City , pin- Code.\n   We make new Sales column which contain total Amount of order.\n   Now we have clean n synchronize data for further use.\n   \n   Column Names And Description:\n   \n   Order_ID--> Customer order ID number.\n   Product-->  Electronics products range / Type of product.\n   Quantity_Ordered--> No of Quantity order by customers.\n   Price_Each--> Price of each indivisual product.\n   Date--> customer purchse product date.\n   Month--. Month column having pruduct perchase months. \n   House_No--> House number from where product is purchase\n   City --> City of purchase address\n   Pin_Code --> Pin_Code of that purchase address area \n   Sales--> Total amount paid by customers.'

# %% [markdown]
# # 4.What is the distribution of sales among different cities in different months?

# %%
city = ds[['City','Sales','Month']].groupby(['City','Month'],as_index=False).agg('sum')
city.tail()
# Out:
#          City  Month      Sales
# 103   Seattle      8  379430.18
# 104   Seattle      9  312738.54
# 105   Seattle     10  633712.52
# 106   Seattle     11  504160.26
# 107   Seattle     12  774635.86

# %%
Atlanta =city.iloc[:12,1:]
Austin = city.iloc[12:24,1:]

# %% [markdown]
# ## Atlanta & Austin city

# %%
fig, axes = plt.subplots(1,2,figsize=(15,5))
fig.suptitle('Distribution of sales among different cities')


# Atlanta
sns.barplot(ax=axes[0], x=Atlanta.Month, y=Atlanta.Sales)
axes[0].set_title('Atlanta City')
axes[0].set_xticklabels(axes[0].get_xticklabels(),rotation = 90)

# Austin
sns.barplot(ax=axes[1],x=Austin.Month, y=Austin.Sales)
axes[1].set_title('Austin city')
ax=axes[1].set_xticklabels(axes[1].get_xticklabels(),rotation = 90)
plt.show()

# %% [markdown]
# ## Boston & Dallas City

# %%
Boston =  city.iloc[24:36,1:]
Dallas =  city.iloc[36:48,1:]

# %%
fig, axes = plt.subplots(1,2,figsize=(15,5))
fig.suptitle('Distribution of sales among different cities')


# Boston
sns.barplot(ax=axes[0], x=Boston.Month, y=Boston.Sales)
axes[0].set_title('Boston City')
axes[0].set_xticklabels(axes[0].get_xticklabels(),rotation = 90)

# Dallas
sns.barplot(ax=axes[1],x=Dallas.Month, y=Dallas.Sales)
axes[1].set_title('Dallas city')
ax=axes[1].set_xticklabels(axes[1].get_xticklabels(),rotation = 90)
plt.show()

# %% [markdown]
# ## Los_Angeles & New_York_City

# %%
Los_Angeles= city.iloc[48:60,1:]
New_York_City= city.iloc[60:72,1:]

# %%
fig, axes = plt.subplots(1,2,figsize=(15,5))
fig.suptitle('Distribution of sales among different cities')


# Los_Angeles
sns.barplot(ax=axes[0], x=Los_Angeles.Month, y=Los_Angeles.Sales)
axes[0].set_title('Los_Angeles')
axes[0].set_xticklabels(axes[0].get_xticklabels(),rotation = 90)

# New_York_City
sns.barplot(ax=axes[1],x=New_York_City.Month, y=New_York_City.Sales)
axes[1].set_title('New_York_City')
ax=axes[1].set_xticklabels(axes[1].get_xticklabels(),rotation = 90)
plt.show()

# %% [markdown]
# ## Portland & San_Francisco

# %%
Portland= city.iloc[72:84,1:]
San_Francisco= city.iloc[84:96,1:]

# %%
fig, axes = plt.subplots(1,2,figsize=(15,5))
fig.suptitle('Distribution of sales among different cities')


# Portland
sns.barplot(ax=axes[0], x=Portland.Month, y=Portland.Sales)
axes[0].set_title('Portland')
axes[0].set_xticklabels(axes[0].get_xticklabels(),rotation = 90)

# San_Francisco
sns.barplot(ax=axes[1],x=San_Francisco.Month, y=San_Francisco.Sales)
axes[1].set_title('San_Francisco')
ax=axes[1].set_xticklabels(axes[1].get_xticklabels(),rotation = 90)
plt.show()

# %% [markdown]
# ## Seattle City

# %%
Seattle= city.iloc[96:108,1:]

# %%
Seattle1=sns.barplot(x=Seattle.Month,y=Seattle.Sales)
plt.setp(Seattle1.get_xticklabels(), rotation=90)
plt.title('Distribution of sales among different cities')

plt.show()

# %% [markdown]
# ## 4a.Which city had the highest sales overall?

# %%
# Grouping citys with their sales 
city = ds[['City','Sales']].groupby(['City'],as_index=False).agg('sum')
city
# Out:
#              City         Sales
# 0         Atlanta  5.590997e+06
# 1          Austin  3.639164e+06
# 2          Boston  7.323284e+06
# 3          Dallas  5.535951e+06
# 4     Los Angeles  1.090514e+07
# 5   New York City  9.328635e+06
# 6        Portland  4.640981e+06
# 7   San Francisco  1.652441e+07
# 8         Seattle  5.495511e+06

# %%
plt.figure(figsize=(15,7))

plt.bar(city['City'],city['Sales'],
      color=['#808080','#800000','#808000','#008000','#000080','#800080','yellow'],width=0.6)

plt.xlabel("City",size=20,color='Blue')
plt.ylabel('Overall sell',size=20,color='red')
plt.title("City wise Overall sell",size=20,color='green')
plt.grid(axis='y')

# %%
# plotting pie chart for better visualization

city_name = city['City']
textprops = {"fontsize":20}

plt.pie(city['Sales'], labels =city_name,autopct='%1.2f%%',radius = 3,startangle = 90,
        shadow = True,textprops =textprops)
plt.show()

# %%
# Value count of city 
ds.City.value_counts()
# Out:
#  San Francisco    89464
#  Los Angeles      59210
#  New York City    49752
#  Boston           39868
#  Atlanta          29762
#  Dallas           29640
#  Seattle          29464
#  Portland         24930
#  Austin           19810
# Name: City, dtype: int64

# %%
'''San Farncisco have higher overall sell in citys . '''
# Out:
# 'San Farncisco have higher overall sell in citys . '

# %% [markdown]
# ## 4b.Which Month had the highest amount of sales overall?

# %%
# Groupby month and sales columns
month = ds[['Month','Sales']].groupby(['Month'],as_index=False).agg('sum')
month.head(3)
# Out:
#    Month         Sales
# 0      1  3.644513e+06
# 1      2  4.404045e+06
# 2      3  5.614201e+06

# %%
# Bar plot for months vs sell
plt.figure(figsize=(15,7))

plt.bar(month['Month'],month['Sales'],
      color=['#808080','#800000','#808000','#008000','#000080','#800080','yellow'],width=0.6)

plt.xlabel("Month",size=20,color='Blue')
plt.ylabel('Overall sell',size=20,color='red')
plt.title("Month wise Overall sell",size=20,color='green')
plt.grid(axis='y')

# %%
# plotting pie chart for better visualization

month_name = ['January', 'February', 'March', 'April',' May','June', 'July', 'August', 'September','October', 'November', 'December']
textprops = {"fontsize":20}

plt.pie(month['Sales'], labels =month_name,autopct='%1.2f%%',radius = 3,startangle = 90,
        shadow = True,textprops =textprops)
plt.show()

# %%
# Value count of months 
ds.Month.value_counts()
# Out:
# 12    49968
# 10    40564
# 4     36558
# 11    35146
# 5     33132
# 3     30306
# 7     28586
# 6     27108
# 2     23950
# 8     23922
# 9     23242
# 1     19418
# Name: Month, dtype: int64

# %%
'''December month having highest amount of overall sell.'''
# Out:
# 'December month having highest amount of overall sell.'

# %% [markdown]
# ## 4C .Most bought products per city.

# %% [markdown]
# ## city which is Most bought products .

# %%
ds.head(2)
# Out:
#   Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
#
#            Order_Date                  Purchase_Address       Date  Month  \
# 0 2019-01-22 21:25:00   944 Walnut St, Boston, MA 02215 2019-01-22      1
# 1 2019-01-28 14:15:00  185 Maple St, Portland, OR 97035 2019-01-28      1
#
#    Year  date       House_No       City   Pin_Code   Sales
# 0  2019    22  944 Walnut St     Boston   MA 02215  700.00
# 1  2019    28   185 Maple St   Portland   OR 97035   14.95

# %%
# Groupby Quantity sold by citys.
cityq = ds[['City','Quantity_Ordered']].groupby(['City'],as_index=False).agg('sum')
cityq.head(2)
# Out:
#        City  Quantity_Ordered
# 0   Atlanta             33204
# 1    Austin             22306

# %%
# Bar plot for total Quantity sold in citys
plt.figure(figsize=(15,7))

plt.bar(cityq['City'],cityq['Quantity_Ordered'],
      color=['#808080','#800000','#808000','#008000','#000080','#800080','yellow'],width=0.6)

plt.xlabel("City",size=20,color='Blue')
plt.ylabel('Ordered_Quantity',size=20,color='red')
plt.title("City wise Quantity sold",size=20,color='green')
plt.grid(axis='y')

# %%
# Pie chart for City wise Quantity sold
city_Quan = cityq['City']
textprops = {"fontsize":20}

plt.pie(cityq['Quantity_Ordered'], labels =city_Quan,autopct='%1.2f%%',radius = 3,startangle = 90,
        shadow = True,textprops =textprops)
plt.show()

# %%
'''San Francisco order highest products as compare to other citys.
   It ordered 24.03% of overall ordered Quantity'''
# Out:
# 'San Francisco order highest products as compare to other citys.\n   It ordered 24.03% of overall ordered Quantity'

# %% [markdown]
# ## Most bought products per city

# %%
# Groupby product Quantity order by citys,
product = ds[['City','Quantity_Ordered','Product']].groupby(['City','Product'],as_index=False).agg('sum')
product.head(2)
# Out:
#        City                 Product  Quantity_Ordered
# 0   Atlanta            20in Monitor               684
# 1   Atlanta  27in 4K Gaming Monitor               986

# %%
citys = ds[['City']].groupby(['City'],as_index=False).agg('sum')
citys
# Out:
#              City
# 0         Atlanta
# 1          Austin
# 2          Boston
# 3          Dallas
# 4     Los Angeles
# 5   New York City
# 6        Portland
# 7   San Francisco
# 8         Seattle

# %%
# Count plot for city and product range
plt.figure(figsize=(12,6))
sns.countplot(ds['City'],hue =ds['Product'])
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
# Out:
# C:\Users\ADESH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
'''Most bought products per city:
   Atlanta ,Austin ,Boston ,Dallas ,Los Angeles ,New York City ,Portland ,San Francisco ,Seattle
   we plot graphs for Quantity ordered of each product in different cities,from that we concludes that :
   
   'AA Batteries (4-pack)'
   'AAA Batteries (4-pack)'
   'Apple Airpods Headphones'
   'Bose SoundSport Headphones'
   'Lightning Charging Cable'
   'USB-C Charging Cable'
   'Wired Headphones
    
   The above product ordered in high quantity in each city .
   'AAA Batteries (4-pack)' Have highest sale as compare to other products in each city.
   Similarly as 2nd highest requirement of product is 'AA Batteries (4-pack)'. '''
# Out:
# "Most bought products per city:\n   Atlanta ,Austin ,Boston ,Dallas ,Los Angeles ,New York City ,Portland ,San Francisco ,Seattle\n   we plot graphs for Quantity ordered of each product in different cities,from that we concludes that :\n   \n   'AA Batteries (4-pack)'\n   'AAA Batteries (4-pack)'\n   'Apple Airpods Headphones'\n   'Bose SoundSport Headphones'\n   'Lightning Charging Cable'\n   'USB-C Charging Cable'\n   'Wired Headphones\n    \n   The above product ordered in high quantity in each city .\n   'AAA Batteries (4-pack)' Have highest sale as compare to other products in each city.\n   Similarly as 2nd highest requirement of product is 'AA Batteries (4-pack)'. "

# %% [markdown]
# ## Based on your analysis, suggest a city for establishing a new branch for the retail store backed with proper reasoning

# %%
'''-I suggest 'San Francisco City' for eastablishing a new branch for retail store .

   -Base on my analysis I concludes that San Francisco have higher sales , we get 23.9% of overall sales from this branch.
   
   -San Francisco order highest products,24.03% of overall ordered Quantityas which are high as compare to other 
    citys thats why I suggest this City.
    
   -To fulfill customers need and to avoide shortage of products in San Francisco City we have to establish 
    a new branch for retail store.
   '''
# Out:
# "-I suggest 'San Francisco City' for eastablishing a new branch for retail store .\n\n   -Base on my analysis I concludes that San Francisco have higher sales , we get 23.9% of overall sales from this branch.\n   \n   -San Francisco order highest products,24.03% of overall ordered Quantityas which are high as compare to other \n    citys thats why I suggest this City.\n    \n   -To fulfill customers need and to avoide shortage of products in San Francisco City we have to establish \n    a new branch for retail store.\n   "

# %% [markdown]
# # 5.Find out the distribution of sales over different times of the day (Morning, Afternoon, Evening, Night) and answer the following for each city

# %%
# To show sales ovee different times we use Time trend plot
ds['Hour'] = ds.Order_Date.dt.hour
ds.head(2)
# Out:
#   Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
#
#            Order_Date                  Purchase_Address       Date  Month  \
# 0 2019-01-22 21:25:00   944 Walnut St, Boston, MA 02215 2019-01-22      1
# 1 2019-01-28 14:15:00  185 Maple St, Portland, OR 97035 2019-01-28      1
#
#    Year  date       House_No       City   Pin_Code   Sales  Hour
# 0  2019    22  944 Walnut St     Boston   MA 02215  700.00    21
# 1  2019    28   185 Maple St   Portland   OR 97035   14.95    14

# %% [markdown]
# # distribution of sales over different times of the day

# %%
# calling the hours and there respective sales 
hrs = ds[['Hour','Sales']].groupby(['Hour'],as_index=False).agg('sum')
hrs.head(2)
# Out:
#    Hour       Sales
# 0     0  1427442.54
# 1     1   921733.76

# %%
# Time trend plot for better visualisation
plt.figure(figsize=(15,7))
# To plot time trend plot 
plt.plot(hrs['Hour'],hrs['Sales'],color='Green',linewidth=5)
hours = hrs['Hour']
plt.xticks(hours)
plt.xlabel("Hour in 24hrs format",size=20,color='Blue')
plt.ylabel('Sales',size=20,color='red')
plt.title("Time Trend of sales of the day",size=20,color='green')
plt.xticks(rotation=90)
plt.grid(True)

# %%
''' -At Morning our Sale rate is slowly increasess as hours move forward, at the end of morning 
     sale will go to the highest point in time trend at11AM to 12PM.
     
    -At Afternoon we have higher sale between 12PM to 6PM most of our products are sold in afternoon time.
    
    -At Evening from 6PM to 9PM our sales rate get slowly decresess.
    
    -At Night Our sale rate is very low sales rate will get decreasess as night start and get
     slowly increasess when moring comes)'''
# Out:
# ' -At Morning our Sale rate is slowly increasess as hours move forward, at the end of morning \n     sale will go to the highest point in time trend at11AM to 12PM.\n     \n    -At Afternoon we have higher sale between 12PM to 6PM most of our products are sold in afternoon time.\n    \n    -At Evening from 6PM to 9PM our sales rate get slowly decresess.\n    \n    -At Night Our sale rate is very low sales rate will get decreasess as night start and get\n     slowly increasess when moring comes)'

# %% [markdown]
# # 5a.What products are mostly sold at different times of the day?

# %%
ds.head(2)
# Out:
#   Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
#
#            Order_Date                  Purchase_Address       Date  Month  \
# 0 2019-01-22 21:25:00   944 Walnut St, Boston, MA 02215 2019-01-22      1
# 1 2019-01-28 14:15:00  185 Maple St, Portland, OR 97035 2019-01-28      1
#
#    Year  date       House_No       City   Pin_Code   Sales  Hour
# 0  2019    22  944 Walnut St     Boston   MA 02215  700.00    21
# 1  2019    28   185 Maple St   Portland   OR 97035   14.95    14

# %%
# calling the hours and their Ordered quantity of each product 
most = ds[['Quantity_Ordered','Product','Hour']].groupby(['Product','Hour'],as_index=False).agg('sum')
most.head(5)
# Out:
#         Product  Hour  Quantity_Ordered
# 0  20in Monitor     0               174
# 1  20in Monitor     1                84
# 2  20in Monitor     2                76
# 3  20in Monitor     3                30
# 4  20in Monitor     4                34

# %%
# Hours of the day
hrss = ds[['Hour']].groupby(['Hour'],as_index=False).agg('sum')
hrss.head(2)
# Out:
#    Hour
# 0     0
# 1     1

# %% [markdown]
# ## products which are Mostly sold at different times of the day:

# %%
# Calling each product which is mostly sold at different time zone 

plt.figure(figsize=(20,10))
#AA Batteries (4-pack)
plt.plot(hrss['Hour'],most.iloc[96:120,2:],linewidth=3)
#AAA Batteries (4-pack)
plt.plot(hrss['Hour'],most.iloc[120:144,2:],linewidth=3)
#Apple Airpods Headphones
plt.plot(hrss['Hour'],most.iloc[144:168,2:],linewidth=3)
#Bose SoundSport Headphones
plt.plot(hrss['Hour'],most.iloc[168:192,2:],linewidth=3)
#Lightning Charging Cable
plt.plot(hrss['Hour'],most.iloc[288:312,2:],linewidth=3)
#USB-C Charging Cable
plt.plot(hrss['Hour'],most.iloc[360:384,2:],linewidth=3)
#Wired Headphones
plt.plot(hrss['Hour'],most.iloc[408:432,2:],linewidth=3)

# Labeling the lines 
plt.legend(['AA Batteries (4-pack)','AAA Batteries (4-pack)','Apple Airpods Headphones','Bose SoundSport Headphones',
            'Lightning Charging Cable','USB-C Charging Cable','Wired Headphones'],prop={"size":20})

hrr = hrss['Hour']
plt.xticks(hrr)
plt.grid(True)
plt.xlabel("Hour in 24hrs format",size=20,color='Blue')
plt.ylabel('Quantity_Ordered',size=20,color='red')
plt.title("Quantity of product ordered vs Hours''",size=20,color='green')
plt.xticks(rotation=90)
plt.grid(True)

# %%
'''Products which are mostly sold at diffeent time zone.
   In above plot we 6 types of product range this products are mostly ordered by customers which are:
   'AA Batteries (4-pack)'
   'AAA Batteries (4-pack)'
   'Apple Airpods Headphones'
   'Bose SoundSport Headphones'
   'Lightning Charging Cable'
   'USB-C Charging Cable'
   'Wired Headphones.
   
   This are the mostly sold products from our product range.
   Our most Ordered products are ordered in 10AM to 9PM time period .
   The graph shows AAA batteries (4pack) are highely ordered in day hours.'''
# Out:
# "Products which are mostly sold at diffeent time zone.\n   In above plot we 6 types of product range this products are mostly ordered by customers which are:\n   'AA Batteries (4-pack)'\n   'AAA Batteries (4-pack)'\n   'Apple Airpods Headphones'\n   'Bose SoundSport Headphones'\n   'Lightning Charging Cable'\n   'USB-C Charging Cable'\n   'Wired Headphones.\n   \n   This are the mostly sold products from our product range.\n   Our most Ordered products are ordered in 10AM to 9PM time period .\n   The graph shows AAA batteries (4pack) are highely ordered in day hours."

# %% [markdown]
# ## products which are less sold at different times of the day:

# %%
plt.figure(figsize=(20,10))
# 20in Monitor
plt.plot(hrss['Hour'],most.iloc[:24,2:])
#27in 4K Gaming Monitor
plt.plot(hrss['Hour'],most.iloc[24:48,2:])
#27in FHD Monitor
plt.plot(hrss['Hour'],most.iloc[48:72,2:])
#34in Ultrawide Monitor
plt.plot(hrss['Hour'],most.iloc[72:96,2:])
#Flatscreen TV
plt.plot(hrss['Hour'],most.iloc[192:216,2:])
#Google Phone
plt.plot(hrss['Hour'],most.iloc[216:240,2:])
#LG Dryer
plt.plot(hrss['Hour'],most.iloc[240:264,2:])
#LG Washing Machine
plt.plot(hrss['Hour'],most.iloc[264:288,2:])
#Macbook Pro Laptop
plt.plot(hrss['Hour'],most.iloc[312:336,2:])
#ThinkPad Laptop
plt.plot(hrss['Hour'],most.iloc[336:360,2:])
#Vareebadd Phone
plt.plot(hrss['Hour'],most.iloc[384:408,2:])
#iPhone
plt.plot(hrss['Hour'],most.iloc[432:456,2:])

hrr = hrss['Hour']
plt.xticks(hrr)
plt.grid(True)
plt.xlabel("Hour in 24hrs format",size=20,color='Blue')
plt.ylabel('Quantity_Ordered',size=20,color='red')
plt.title("Quantity of product ordered vs Hours''",size=20,color='green')
plt.xticks(rotation=90)
plt.grid(True)

# %%
''' We seaperate out the most sold and less sold products .
    In above plot we have remaing product range which are less sold in hours as compare to above 6 products.'''
# Out:
# ' We seaperate out the most sold and less sold products .\n    In above plot we have remaing product range which are less sold in hours as compare to above 6 products.'

# %% [markdown]
# ## Quantity_Ordered at different hours of the day

# %%
# calling the hours and there respective sales 
hr = ds[['Quantity_Ordered','Hour']].groupby(['Hour'],as_index=False).agg('sum')
hr.head(2)
# Out:
#    Hour  Quantity_Ordered
# 0     0              8856
# 1     1              5238

# %%
# Time trend plot for better visualisation
plt.figure(figsize=(15,7))
# To plot time trend plot 
plt.bar(hr['Hour'],hr['Quantity_Ordered'],color='Green',linewidth=2)

plot3=sns.barplot(x=hr.Hour,y=hr.Quantity_Ordered)
plt.setp(plot3.get_xticklabels(), rotation=90)

plt.xlabel("Hour in 24hrs format",size=20,color='Blue')
plt.ylabel('Quantity_Ordered',size=20,color='red')
plt.title("Quantity_Ordered at diff hours ",size=20,color='green')
plt.xticks(rotation=90)
plt.grid(True)

# %%
'''From above graph we can easyly concludes the best working hours .
   Graph shows total Quantity_Ordered with different time zones.
   From graph we can say that our Products are mostly ordered in Afternoon and Evening time .'''
# Out:
# 'From above graph we can easyly concludes the best working hours .\n   Graph shows total Quantity_Ordered with different time zones.\n   From graph we can say that our Products are mostly ordered in Afternoon and Evening time .'

# %% [markdown]
# # Based on your analysis, suggest the best working hours and the best products for the retail stores in each city

# %%
'''Base on my analysis I concludes that The best working hours are between Afternoon & Evening  time.
   Our most of the products are Ordered  in between 11AM to 9PM and our sale is also high in between this period.
   So my suggestion is from Morning 10AM to 9PM are best working hours.
   We specially have to focus on 11Am to 2PM and 7PM to 9 PM.
   
   Best Working Hours for retail stores in citys:
   11AM to 9PM
   
   Best Products for retail stores in eaach citys :
   'AA Batteries (4-pack)'
   'AAA Batteries (4-pack)'
   'Apple Airpods Headphones'
   'Bose SoundSport Headphones'
   'Lightning Charging Cable'
   'USB-C Charging Cable'
   'Wired Headphones
   
   We suggest this products beacuase most of our sales is comes from this products. 
   Each city requirement for this products is high, so i suggest this products for retail store'''
# Out:
# "Base on my analysis I concludes that The best working hours are between Afternoon & Evening  time.\n   Our most of the products are Ordered  in between 11AM to 9PM and our sale is also high in between this period.\n   So my suggestion is from Morning 10AM to 9PM are best working hours.\n   We specially have to focus on 11Am to 2PM and 7PM to 9 PM.\n   \n   Best Working Hours for retail stores in citys:\n   11AM to 9PM\n   \n   Best Products for retail stores in eaach citys :\n   'AA Batteries (4-pack)'\n   'AAA Batteries (4-pack)'\n   'Apple Airpods Headphones'\n   'Bose SoundSport Headphones'\n   'Lightning Charging Cable'\n   'USB-C Charging Cable'\n   'Wired Headphones\n   \n   We suggest this products beacuase most of our sales is comes from this products. \n   Each city requirement for this products is high, so i suggest this products for retail store"

# %% [markdown]
# # 6.Find out the pair of products that are most sold together. For example, generally, we would expect a person who buys an iPhone 11 to also buy the Apple Airpods together with it. Identify such pairs of products and suggest what promotional offers should the retail company come up with based on your outcome.

# %%
ds.head()
# Out:
#   Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order_Date                       Purchase_Address       Date  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215 2019-01-22
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035 2019-01-28
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016 2019-01-17
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001 2019-01-05
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301 2019-01-25
#
#    Month  Year  date       House_No            City   Pin_Code   Sales  Hour
# ...

# %%
ds.duplicated().value_counts()
# Out:
# True     186214
# False    185686
# dtype: int64

# %%
df = ds.drop_duplicates(subset=None,keep='first',inplace=False)
df['Grouped'] = df.groupby('Order_ID')['Product'].transform(lambda x: ','.join(x))
df = df[['Order_ID', 'Grouped']].drop_duplicates()
df.head(20)
# Out:
# <ipython-input-101-51fd6d8241b7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order_ID')['Product'].transform(lambda x: ','.join(x))
#    Order_ID                     Grouped
# 0    141234                      iPhone
# 1    141235    Lightning Charging Cable
# 2    141236            Wired Headphones
# 3    141237            27in FHD Monitor
# 4    141238            Wired Headphones
# 5    141239      AAA Batteries (4-pack)
# 6    141240      27in 4K Gaming Monitor
# 7    141241        USB-C Charging Cable
# 8    141242  Bose SoundSport Headphones
# 9    141243    Apple Airpods Headphones
# 10   141244    Apple Airpods Headphones
# 11   141245          Macbook Pro Laptop
# ...

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))
    
for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1002
# ('Google Phone', 'USB-C Charging Cable') 985
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 413
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 159
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
'''Pairs of products that are most sold together:

('iPhone', 'Lightning Charging Cable')

('Google Phone', 'USB-C Charging Cable') 

('iPhone', 'Wired Headphones') 

('Google Phone', 'Wired Headphones') 

('Vareebadd Phone', 'USB-C Charging Cable')

('iPhone', 'Apple Airpods Headphones') 

('Google Phone', 'Bose SoundSport Headphones') 

('USB-C Charging Cable', 'Wired Headphones') 

('Vareebadd Phone', 'Wired Headphones') 

('Lightning Charging Cable', 'Wired Headphones')


We have to provide offer on products which have high cost,like iphone, Google phone , Vareebadd Phone.
We have pairs of products which are buy at same time by same customer.
By using this pairs we can able to put offers .
'''
# Out:
# "Pairs of products that are most sold together:\n\n('iPhone', 'Lightning Charging Cable')\n\n('Google Phone', 'USB-C Charging Cable') \n\n('iPhone', 'Wired Headphones') \n\n('Google Phone', 'Wired Headphones') \n\n('Vareebadd Phone', 'USB-C Charging Cable')\n\n('iPhone', 'Apple Airpods Headphones') \n\n('Google Phone', 'Bose SoundSport Headphones') \n\n('USB-C Charging Cable', 'Wired Headphones') \n\n('Vareebadd Phone', 'Wired Headphones') \n\n('Lightning Charging Cable', 'Wired Headphones')\n\n\nWe have to provide offer on products which have high cost,like iphone, Google phone , Vareebadd Phone.\nWe have pairs of products which are buy at same time by same customer.\nBy using this pairs we can able to put offers .\n"
